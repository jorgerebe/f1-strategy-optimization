# %%
from racesim.racesimulation import RaceSimulation
from racesim.config import *
import pandas as pd
import numpy as np
import time
import gymnasium as gym
from tqdm import tqdm

# %%
from stable_baselines3.dqn import DQN
from stable_baselines3.a2c import A2C
from sb3_contrib.qrdqn import QRDQN

# %%
from gymnasium_env.envs.f1_env import RewardFunctionPerPositionAtFinalLap
from gymnasium_env.envs.f1_env import RewardFunctionPositionChangeByLapsToGo
from gymnasium_env.envs.f1_env import RewardFunctionPositionChange
from gymnasium_env.envs.f1_env import RewardFunctionPerPositionAtFinalLapEval

# %%
n_seeds = 1000
n_races_to_test = 1

# %% [markdown]
# ## RANDOM

# %% [markdown]
# ### RANDOMNESS = 0

# %%
finish_positions_base = []
start_positions_base = []

for seed in tqdm(range(n_seeds)):
    env_basic = gym.make('F1Env/Basic-v0',seed=seed, reward_function = RewardFunctionPerPositionAtFinalLapEval(),
                     grid_config=GridConfigMixed(), control_driver=False, randomness=0)
    obs, info = env_basic.reset()
    start_positions_base.append(env_basic.our_driver.position)
    # print(env_basic.our_driver.tyre.__dict__)
    done = False
    total_rw = 0
    
    while not done:
        next_obs, reward, terminated, truncated, info = env_basic.step(0)

        total_rw += reward
        done = terminated or truncated
        obs = next_obs
    finish_positions_base.append(env_basic.our_driver.position)

# print(start_positions_base)
# print(finish_positions_base)
print(np.array(finish_positions_base).mean())
np.array(finish_positions_base).std()
# Out:
#  10%|████                                    | 101/1000 [00:47<07:07,  2.11it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 5
#       2 start_positions_base = []
#       4 for seed in tqdm(range(n_seeds)):
# ----> 5     env_basic = gym.make('F1Env/Basic-v0',seed=seed, reward_function = RewardFunctionPerPositionAtFinalLapEval(),
#       6                      grid_config=GridConfigMixed(), control_driver=False, randomness=0)
#       7     obs, info = env_basic.reset()
#       8     start_positions_base.append(env_basic.our_driver.position)
#
# File ~/miniconda3/envs/rfl/lib/python3.11/site-packages/gymnasium/envs/registration.py:801, in make(id, max_episode_steps, autoreset, apply_api_compatibility, disable_env_checker, **kwargs)
#     798     render_mode = None
#     800 try:
# --> 801     env = env_creator(**env_spec_kwargs)
#     802 except TypeError as e:
#     803     if (
#     804         str(e).find("got an unexpected keyword argument 'render_mode'") >= 0
#     805         and apply_human_rendering
#     806     ):
#
# File ~/miniconda3/envs/rfl/lib/python3.11/site-packages/gymnasium_env/envs/f1_env.py:50, in F1Env.__init__(self, render_mode, seed, reward_function, grid_config, control_driver, randomness)
#      46 #actions of the agent are for the driver with id = n_drivers-1
#      48 rand_gen = np.random.default_rng(seed)
# ---> 50 config = Config(rand_gen, grid_config=grid_config, control_driver=self.control_driver)
#      52 self.n_drivers = config.n_drivers
#      53 self.n_laps = 0
#
# File ~/miniconda3/envs/rfl/lib/python3.11/site-packages/racesim/config.py:55, in Config.__init__(self, rand_generator, route, grid_config, control_driver)
#      52 circuits = config["circuits"]
#      54 for circuit in circuits:
# ---> 55     self.circuit_configs.append(RaceParameters(circuit,
#      56                                                 self.rand_generator,
#      57                                                 self.n_drivers,
#      58                                                 self.driver_being_controlled_id,
#      59                                                 grid_config,
#      60                                                 control_driver))
#
# File ~/miniconda3/envs/rfl/lib/python3.11/site-packages/racesim/config.py:117, in RaceParameters.__init__(self, circuit_config, rand_generator, n_drivers, driver_to_control, grid_config, control_driver)
#     105     pitstops = [PitStopInfo(self.rand_generator,
#     106                             pitstop["lap_number"],
#     107                             self.tyre_types[self.tyre_type_to_id[pitstop["tyre"]]],
#     108                             pitstop["lap_var"])
#     109                                 for pitstop in strategy["pitStops"]]
#     111     self.strategies.append(Strategy(strategy["name"],
#     112                                     self.tyre_types[self.tyre_type_to_id
#     113                                                     [strategy["start_tyre"]]],
#     114                                     pitstops,
#     115                                     strategy["probability"]))
# --> 117 self.drivers = [Driver(i, None,
#     118                        self.get_min_fuel_to_complete_race(),
#     119                        self.n_laps, i+1, self.start_interval,
#     120                        self.pit) for i in range(self.n_drivers)]
#     123 self.driver_being_controlled = self.drivers[self.driver_being_controlled_id]
#     125 self.drivers = self.get_drivers()
#
# File ~/miniconda3/envs/rfl/lib/python3.11/site-packages/racesim/config.py:117, in <listcomp>(.0)
#     105     pitstops = [PitStopInfo(self.rand_generator,
#     106                             pitstop["lap_number"],
#     107                             self.tyre_types[self.tyre_type_to_id[pitstop["tyre"]]],
#     108                             pitstop["lap_var"])
#     109                                 for pitstop in strategy["pitStops"]]
#     111     self.strategies.append(Strategy(strategy["name"],
#     112                                     self.tyre_types[self.tyre_type_to_id
#     113                                                     [strategy["start_tyre"]]],
#     114                                     pitstops,
#     115                                     strategy["probability"]))
# --> 117 self.drivers = [Driver(i, None,
#     118                        self.get_min_fuel_to_complete_race(),
#     119                        self.n_laps, i+1, self.start_interval,
#     120                        self.pit) for i in range(self.n_drivers)]
#     123 self.driver_being_controlled = self.drivers[self.driver_being_controlled_id]
#     125 self.drivers = self.get_drivers()
#
# File ~/miniconda3/envs/rfl/lib/python3.11/site-packages/racesim/driver.py:39, in Driver.__init__(self, identifier, strategy, fuel, n_laps, position, interval, pit)
#      36 self.gap = 0
#      37 self.n_stops = 0
# ---> 39 self.reset(strategy, fuel, n_laps, position, interval)
#
# File ~/miniconda3/envs/rfl/lib/python3.11/site-packages/racesim/driver.py:194, in Driver.reset(self, strategy, fuel, n_laps, position, interval)
#     190 self.percentage_of_lap_completed = 0
#     192 self.modes = PriorityQueue()
# --> 194 self.laps_progress = np.frompyfunc(list, 0, 1)(np.empty((self.laps_to_go), dtype=object))
#
# KeyboardInterrupt:

# %% [markdown]
# ### RANDOMNESS = 1

# %%
finish_positions_base_1 = []
start_positions_base_1 = []

for seed in tqdm(range(n_seeds)):
    env_basic = gym.make('F1Env/Basic-v0',seed=seed, reward_function = RewardFunctionPerPositionAtFinalLapEval(),
                     grid_config=GridConfigMixed(), control_driver=False, randomness=1)
    obs, info = env_basic.reset()
    start_positions_base_1.append(env_basic.our_driver.position)
    # print(env_basic.our_driver.tyre.__dict__)
    done = False
    total_rw = 0
    
    while not done:
        next_obs, reward, terminated, truncated, info = env_basic.step(0)

        total_rw += reward
        done = terminated or truncated
        obs = next_obs
    finish_positions_base_1.append(env_basic.our_driver.position)

# print(start_positions_base)
# print(finish_positions_base)
print(np.array(finish_positions_base_1).mean())
np.array(finish_positions_base_1).std()
# Out:
# 100%|███████████████████████████████████████| 1000/1000 [07:50<00:00,  2.13it/s]
# 13.485
# 4.682710219520315

# %% [markdown]
# ### RANDOMNESS = 2

# %%
finish_positions_base_2 = []
start_positions_base_2 = []

for seed in tqdm(range(n_seeds)):
    env_basic = gym.make('F1Env/Basic-v0',seed=seed, reward_function = RewardFunctionPerPositionAtFinalLapEval(),
                     grid_config=GridConfigMixed(), control_driver=False, randomness=2)
    obs, info = env_basic.reset()
    start_positions_base_2.append(env_basic.our_driver.position)
    # print(env_basic.our_driver.tyre.__dict__)
    done = False
    total_rw = 0
    
    while not done:
        next_obs, reward, terminated, truncated, info = env_basic.step(0)

        total_rw += reward
        done = terminated or truncated
        obs = next_obs
    finish_positions_base_2.append(env_basic.our_driver.position)

# print(start_positions_base)
# print(finish_positions_base)
print(np.array(finish_positions_base_2).mean())
np.array(finish_positions_base_2).std()
# Out:
# 100%|███████████████████████████████████████| 1000/1000 [07:55<00:00,  2.10it/s]
# 16.219
# 4.641663387192138

# %%
env_basic = gym.make('F1Env/Basic-v0',seed=1, reward_function = RewardFunctionPerPositionAtFinalLapEval(),
                     grid_config=GridConfigMixed(), control_driver=False, randomness=2)
obs, info = env_basic.reset()
start_positions_base_2.append(env_basic.our_driver.position)
print(env_basic.our_driver.tyre.__dict__)
print(env_basic.our_driver.position)

for pit in env_basic.our_driver.strategy.pitstops:
    print(pit.__dict__)
    print(pit.tyre.__dict__)
    print("------")
# print(env_basic.our_driver.strategy.pitstops[1].tyre.__dict__)
done = False
total_rw = 0

while not done:
    display(env_basic.race_simulation.to_df())
    next_obs, reward, terminated, truncated, info = env_basic.step(0)

    total_rw += reward
    done = terminated or truncated
    obs = next_obs
print(env_basic.our_driver.position)
display(env_basic.race_simulation.to_df())
# Out:
# {'compound': 0, 'base_lap_time': 70.0122, 'squared_deg': 0.00281, 'linear_deg': -0.01999, 'used_laps': 0}
# 14
# {'rand_generator': Generator(PCG64) at 0x7F81B8A3FA00, 'lap_number': 31, 'tyre': <racesim.tyre.TyreType object at 0x7f81b292fcd0>, 'lap_var': 0}
# {'rand_generator': Generator(PCG64) at 0x7F81B8A3FA00, 'type_id': 2, 'name': 'hard', 'base_lap_time': 71.1, 'squared_deg': 0.0016, 'linear_deg': -0.014, 'perf_var': 0.01, 'deg_var': 5e-05}
# ------
# {'rand_generator': Generator(PCG64) at 0x7F81B8A3FA00, 'lap_number': 45, 'tyre': <racesim.tyre.TyreType object at 0x7f81b20e7550>, 'lap_var': 0}
# {'rand_generator': Generator(PCG64) at 0x7F81B8A3FA00, 'type_id': 0, 'name': 'soft', 'base_lap_time': 70, 'squared_deg': 0.0028, 'linear_deg': -0.02, 'perf_var': 0.02, 'deg_var': 5e-05}
# ------
# {'rand_generator': Generator(PCG64) at 0x7F81B8A3FA00, 'lap_number': 76, 'tyre': <racesim.tyre.TyreType object at 0x7f81b20e6c90>, 'lap_var': 0}
# {'rand_generator': Generator(PCG64) at 0x7F81B8A3FA00, 'type_id': 1, 'name': 'medium', 'base_lap_time': 70.5, 'squared_deg': 0.002, 'linear_deg': -0.018, 'perf_var': 0.015, 'deg_var': 5e-05}
# ------
#     id  interval  percentage  gap  lapsToGo  lastLapTime  position  \
# 0    5       0.0    0.000000  0.0        78            1         1
# 1    2       0.4   -0.005195  0.4        78            1         2
# 2    6       0.4   -0.010391  0.8        78            1         3
# 3    0       0.4   -0.015582  1.2        78            1         4
# 4   15       0.4   -0.020778  1.6        78            1         5
# 5   13       0.4   -0.025976  2.0        78            1         6
# 6    4       0.4   -0.031177  2.4        78            1         7
# 7    9       0.4   -0.036123  2.8        78            1         8
# 8   17       0.4   -0.041553  3.2        78            1         9
# 9   16       0.4   -0.046457  3.6        78            1        10
# 10   8       0.4   -0.051961  4.0        78            1        11
# 11  10       0.4   -0.057128  4.4        78            1        12
# 12  18       0.4   -0.061454  4.8        78            1        13
# 13  19       0.4   -0.067522  5.2        78            1        14
# 14   7       0.4   -0.072733  5.6        78            1        15
# 15  12       0.4   -0.077434  6.0        78            1        16
# 16   1       0.4   -0.083123  6.4        78            1        17
# 17  14       0.4   -0.087755  6.8        78            1        18
# 18  11       0.4   -0.093504  7.2        78            1        19
# 19   3       0.4   -0.098687  7.6        78            1        20
#
#     potentialLapTime  compound  usedLaps  secondDry  nStops
# 0           77.50032         1         0      False       0
# 1           76.99552         0         0      False       0
# 2           76.98772         0         0      False       0
# 3           77.01002         0         0      False       0
# 4           77.00542         0         0      False       0
# 5           76.99502         0         0      False       0
# 6           76.98042         0         0      False       0
# 7           77.51382         1         0      False       0
# 8           77.00962         0         0      False       0
# 9           77.49102         1         0      False       0
# 10          76.98042         0         0      False       0
# 11          77.01972         0         0      False       0
# 12          78.10672         2         0      False       0
# 13          77.01192         0         0      False       0
# 14          76.99422         0         0      False       0
# 15          77.48552         1         0      False       0
# 16          76.99462         0         0      False       0
# 17          77.48852         1         0      False       0
# 18          77.00222         0         0      False       0
# 19          77.01142         0         0      False       0
# 15
#     id   interval  percentage        gap  lapsToGo  lastLapTime  position  \
# 0    9   0.000000           0   0.000000         0    73.188400         1
# 1    5  14.853253           0  14.853253         0    72.041371         2
# 2   16  20.585655           0  35.438908         0    73.766153         3
# 3   14  14.100602           0  49.539510         0    73.447801         4
# 4    6   6.273081           0  55.812591         0    75.616789         5
# 5   12   0.095682           0  55.908273         0    73.759801         6
# 6   15   2.523899           0  58.432172         0    75.797029         7
# 7    4   0.818575           0  59.250747         0    75.624409         8
# 8    2   1.064886           0  60.315633         0    75.798655         9
# 9    8   1.482207           0  61.797840         0    75.854865        10
# 10  17   0.233519           0  62.031359         0    75.996297        11
# 11  10   0.058514           0  62.089873         0    75.720943        12
# 12  13   8.295555           0  70.385428         0    75.889358        13
# 13   7   0.121685           0  70.507113         0    71.770935        14
# 14  19   0.074642           0  70.581754         0    71.539548        15
# 15  11   0.075400           0  70.657155         0    75.865745        16
# 16  18   0.231860           0  70.889015         0    71.557618        17
# 17   1   0.290764           0  71.179779         0    71.323066        18
# 18   3   0.301222           0  71.481001         0    71.320023        19
# 19   0  11.283819           0  82.764820         0    75.894093        20
#
#     potentialLapTime  compound  usedLaps  secondDry  nStops
# 0           73.28942         0        38       True       1
# 1           72.10598         0        31       True       1
# 2           73.88438         0        41       True       1
# 3           73.55810         0        39       True       1
# 4           75.69590         2        59       True       1
# 5           73.25224         0        38       True       1
# 6           75.88190         2        59       True       1
# 7           75.70350         2        59       True       1
# 8           75.88330         2        59       True       1
# 9           75.94290         2        59       True       1
# 10          75.74450         2        59       True       1
# 11          75.80450         2        59       True       1
# 12          75.97850         2        59       True       1
# 13          70.47522         1         2       True       3
# 14          70.48488         1         2       True       3
# 15          70.48114         1         2       True       3
# 16          70.63010         0        19       True       1
# 17          70.47314         1         2       True       3
# 18          70.48096         1         2       True       3
# 19          75.98370         2        59       True       1

# %% [markdown]
# ## DQN

# %% [markdown]
# ### R1

# %%
dqn_r1_start = []
dqn_r1_finish = []
agent = DQN.load("dqn_r1_best_model.zip")

for seed in tqdm(range(n_seeds)):
    env_basic = gym.make('F1Env/Basic-v0',seed=seed, reward_function = RewardFunctionPerPositionAtFinalLapEval(),
                     grid_config=GridConfigMixed(), control_driver=True)
    obs, info = env_basic.reset()
    dqn_r1_start.append(env_basic.our_driver.position)
    # print(env_basic.our_driver.tyre.__dict__, " - Start Position: ", env_basic.our_driver.position)
    done = False
    total_rw = 0
    stops = 0
    
    while not done:
        action, _ = agent.predict(obs, deterministic=True)
        if action != 0:
            stops += 1
        next_obs, reward, terminated, truncated, info = env_basic.step(action)

        total_rw += reward
        done = terminated or truncated
        obs = next_obs
    dqn_r1_finish.append(env_basic.our_driver.position)
    # print("STOPS: ", stops)

# print(dqn_r3_start)
# print(dqn_r3_finish)
print(np.array(dqn_r1_finish).mean())
print(np.array(dqn_r1_finish).std())
# Out:
# 100%|███████████████████████████████████████| 1000/1000 [09:34<00:00,  1.74it/s]
# 12.424
# 5.454009900981112

# %% [markdown]
# ### R2

# %%
dqn_r2_start = []
dqn_r2_finish = []
agent = DQN.load("dqn_r2_best_model.zip")

for seed in tqdm(range(n_seeds)):
    env_basic = gym.make('F1Env/Basic-v0',seed=seed, reward_function = RewardFunctionPerPositionAtFinalLapEval(),
                     grid_config=GridConfigMixed(), control_driver=True)
    obs, info = env_basic.reset()
    dqn_r2_start.append(env_basic.our_driver.position)
    # print(env_basic.our_driver.tyre.__dict__, " - Start Position: ", env_basic.our_driver.position)
    done = False
    total_rw = 0
    stops = 0
    
    while not done:
        action, _ = agent.predict(obs, deterministic=True)
        if action != 0:
            stops += 1
        next_obs, reward, terminated, truncated, info = env_basic.step(action)

        total_rw += reward
        done = terminated or truncated
        obs = next_obs
    dqn_r2_finish.append(env_basic.our_driver.position)
    # print("STOPS: ", stops)

# print(dqn_r3_start)
# print(dqn_r3_finish)
print(np.array(dqn_r2_finish).mean())
print(np.array(dqn_r2_finish).std())
# Out:
# 100%|███████████████████████████████████████| 1000/1000 [09:46<00:00,  1.70it/s]
# 11.904
# 4.4028154628601

# %% [markdown]
# ### R3

# %%
dqn_r3_start = []
dqn_r3_finish = []
agent = DQN.load("dqn_r3_best_model.zip")

for seed in tqdm(range(n_seeds)):
    env_basic = gym.make('F1Env/Basic-v0',seed=seed, reward_function = RewardFunctionPerPositionAtFinalLapEval(),
                     grid_config=GridConfigMixed(), control_driver=True)
    obs, info = env_basic.reset()
    dqn_r3_start.append(env_basic.our_driver.position)
    # print(env_basic.our_driver.tyre.__dict__, " - Start Position: ", env_basic.our_driver.position)
    done = False
    total_rw = 0
    stops = 0
    
    while not done:
        action, _ = agent.predict(obs, deterministic=True)
        if action != 0:
            stops += 1
        next_obs, reward, terminated, truncated, info = env_basic.step(action)

        total_rw += reward
        done = terminated or truncated
        obs = next_obs
    dqn_r3_finish.append(env_basic.our_driver.position)
    # print("STOPS: ", stops)

# print(dqn_r3_start)
# print(dqn_r3_finish)
print(np.array(dqn_r3_finish).mean())
print(np.array(dqn_r3_finish).std())
# Out:
# 100%|███████████████████████████████████████| 1000/1000 [09:32<00:00,  1.75it/s]
# 12.998
# 5.492540031715746

# %% [markdown]
# ## A2C

# %% [markdown]
# ### R1

# %%
a2c_r1_start = []
a2c_r1_finish = []
agent = A2C.load("a2c_r1_best_model.zip")

for seed in tqdm(range(n_seeds)):
    env_basic = gym.make('F1Env/Basic-v0',seed=seed, reward_function = RewardFunctionPerPositionAtFinalLapEval(),
                     grid_config=GridConfigMixed(), control_driver=True)
    obs, info = env_basic.reset()
    a2c_r1_start.append(env_basic.our_driver.position)
    # print(env_basic.our_driver.tyre.__dict__, " - Start Position: ", env_basic.our_driver.position)
    done = False
    total_rw = 0
    stops = 0
    
    while not done:
        action, _ = agent.predict(obs, deterministic=True)
        if action != 0:
            stops += 1
        next_obs, reward, terminated, truncated, info = env_basic.step(action)

        total_rw += reward
        done = terminated or truncated
        obs = next_obs
    a2c_r1_finish.append(env_basic.our_driver.position)
    # print("STOPS: ", stops)

# print(a2c_r1_start
# print(a2c_r1_finish)
print(np.array(a2c_r1_finish).mean())
print(np.array(a2c_r1_finish).std())
# Out:
# 100%|███████████████████████████████████████| 1000/1000 [10:17<00:00,  1.62it/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 27
#      24     a2c_r1_finish.append(env_basic.our_driver.position)
#      25     # print("STOPS: ", stops)
# ---> 27 print(dqn_r2_start)
#      28 print(dqn_r2_finish)
#      29 print(np.array(a2c_r1_finish).mean())
#
# NameError: name 'dqn_r2_start' is not defined

# %%
print(np.array(a2c_r1_finish).mean())
print(np.array(a2c_r1_finish).std())
# Out:
# 10.573
# 6.445515572861492

# %% [markdown]
# ### R2

# %%
a2c_r2_start = []
a2c_r2_finish = []
agent = A2C.load("a2c_r2_best_model.zip")

for seed in tqdm(range(n_seeds)):
    env_basic = gym.make('F1Env/Basic-v0',seed=seed, reward_function = RewardFunctionPerPositionAtFinalLapEval(),
                     grid_config=GridConfigMixed(), control_driver=True)
    obs, info = env_basic.reset()
    a2c_r2_start.append(env_basic.our_driver.position)
    # print(env_basic.our_driver.tyre.__dict__, " - Start Position: ", env_basic.our_driver.position)
    done = False
    total_rw = 0
    stops = 0
    
    while not done:
        action, _ = agent.predict(obs, deterministic=True)
        if action != 0:
            stops += 1
        next_obs, reward, terminated, truncated, info = env_basic.step(action)

        total_rw += reward
        done = terminated or truncated
        obs = next_obs
    a2c_r2_finish.append(env_basic.our_driver.position)
    # print("STOPS: ", stops)

# print(a2c_r1_start
# print(a2c_r1_finish)
print(np.array(a2c_r2_finish).mean())
print(np.array(a2c_r2_finish).std())
# Out:
# 100%|███████████████████████████████████████| 1000/1000 [10:22<00:00,  1.61it/s]
# 14.389
# 3.831928887649143

# %% [markdown]
# ### R3

# %%
a2c_r3_start = []
a2c_r3_finish = []
agent = A2C.load("a2c_r3_2_latest.zip")

for seed in tqdm(range(n_seeds)):
    env_basic = gym.make('F1Env/Basic-v0',seed=seed, reward_function = RewardFunctionPerPositionAtFinalLapEval(),
                     grid_config=GridConfigMixed(), control_driver=True)
    obs, info = env_basic.reset()
    a2c_r3_start.append(env_basic.our_driver.position)
    # print(env_basic.our_driver.tyre.__dict__, " - Start Position: ", env_basic.our_driver.position)
    done = False
    total_rw = 0
    stops = 0
    
    while not done:
        action, _ = agent.predict(obs, deterministic=True)
        if action != 0:
            stops += 1
        next_obs, reward, terminated, truncated, info = env_basic.step(action)

        total_rw += reward
        done = terminated or truncated
        obs = next_obs
    a2c_r3_finish.append(env_basic.our_driver.position)
    # print("STOPS: ", stops)

# print(a2c_r1_start
# print(a2c_r1_finish)
print(np.array(a2c_r3_finish).mean())
print(np.array(a2c_r3_finish).std())
# Out:
# 100%|███████████████████████████████████████| 1000/1000 [09:35<00:00,  1.74it/s]
# 7.445
# 5.329256514749501

# %% [markdown]
# ## QR-DQN

# %% [markdown]
# ### R1

# %%
qr_dqn_r1_start = []
qr_dqn_r1_finish = []
agent = QRDQN.load("qr-dqn_r1_best_model.zip")

for seed in tqdm(range(n_seeds)):
    env_basic = gym.make('F1Env/Basic-v0',seed=seed, reward_function = RewardFunctionPerPositionAtFinalLapEval(),
                     grid_config=GridConfigMixed(), control_driver=True)
    obs, info = env_basic.reset()
    qr_dqn_r1_start.append(env_basic.our_driver.position)
    # print(env_basic.our_driver.tyre.__dict__, " - Start Position: ", env_basic.our_driver.position)
    done = False
    total_rw = 0
    stops = 0
    
    while not done:
        action, _ = agent.predict(obs, deterministic=True)
        if action != 0:
            stops += 1
        next_obs, reward, terminated, truncated, info = env_basic.step(action)

        total_rw += reward
        done = terminated or truncated
        obs = next_obs
    qr_dqn_r1_finish.append(env_basic.our_driver.position)
    # print("STOPS: ", stops)

# print(a2c_r1_start
# print(a2c_r1_finish)
print(np.array(qr_dqn_r1_finish).mean())
print(np.array(qr_dqn_r1_finish).std())
# Out:
# 100%|███████████████████████████████████████| 1000/1000 [09:58<00:00,  1.67it/s]
# 11.974
# 6.070529136739235

# %% [markdown]
# ### R2

# %%
qr_dqn_r2_start = []
qr_dqn_r2_finish = []
agent = QRDQN.load("qr_dqn_r2_3_last.zip")

for seed in tqdm(range(n_seeds)):
    env_basic = gym.make('F1Env/Basic-v0',seed=seed, reward_function = RewardFunctionPerPositionAtFinalLapEval(),
                     grid_config=GridConfigMixed(), control_driver=True)
    obs, info = env_basic.reset()
    qr_dqn_r2_start.append(env_basic.our_driver.position)
    # print(env_basic.our_driver.tyre.__dict__, " - Start Position: ", env_basic.our_driver.position)
    done = False
    total_rw = 0
    stops = 0
    
    while not done:
        action, _ = agent.predict(obs, deterministic=True)
        if action != 0:
            stops += 1
        next_obs, reward, terminated, truncated, info = env_basic.step(action)

        total_rw += reward
        done = terminated or truncated
        obs = next_obs
    qr_dqn_r2_finish.append(env_basic.our_driver.position)
    # print("STOPS: ", stops)

# print(a2c_r1_start
# print(a2c_r1_finish)
print(np.array(qr_dqn_r2_finish).mean())
print(np.array(qr_dqn_r2_finish).std())
# Out:
# 100%|███████████████████████████████████████| 1000/1000 [09:29<00:00,  1.76it/s]
# 14.966
# 3.6609894837325063

# %% [markdown]
# ### R3

# %%
qr_dqn_r3_start = []
qr_dqn_r3_finish = []
agent = QRDQN.load("qr_dqn_r3_3_last.zip")

for seed in tqdm(range(n_seeds)):
    env_basic = gym.make('F1Env/Basic-v0',seed=seed, reward_function = RewardFunctionPerPositionAtFinalLapEval(),
                     grid_config=GridConfigMixed(), control_driver=True)
    obs, info = env_basic.reset()
    qr_dqn_r3_start.append(env_basic.our_driver.position)
    # print(env_basic.our_driver.tyre.__dict__, " - Start Position: ", env_basic.our_driver.position)
    done = False
    total_rw = 0
    stops = 0
    
    while not done:
        action, _ = agent.predict(obs, deterministic=True)
        if action != 0:
            stops += 1
        next_obs, reward, terminated, truncated, info = env_basic.step(action)

        total_rw += reward
        done = terminated or truncated
        obs = next_obs
    qr_dqn_r3_finish.append(env_basic.our_driver.position)
    # print("STOPS: ", stops)

# print(a2c_r1_start
# print(a2c_r1_finish)
print(np.array(qr_dqn_r3_finish).mean())
print(np.array(qr_dqn_r3_finish).std())
# Out:
# 100%|███████████████████████████████████████| 1000/1000 [09:33<00:00,  1.74it/s]
# 15.026
# 4.1657321085254635
