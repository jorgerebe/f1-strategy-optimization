# %%
from stable_baselines3 import DQN
from stable_baselines3.dqn import MlpPolicy
from stable_baselines3 import PPO
from typing import TYPE_CHECKING, Any, Callable, Dict, List, Optional, Union
from stable_baselines3.common.callbacks import EvalCallback, BaseCallback
from stable_baselines3.common.vec_env import DummyVecEnv, VecEnv, sync_envs_normalization
from stable_baselines3.common.monitor import Monitor
import gymnasium as gym

# %%
from gymnasium_env.envs.f1_env import RewardFunction
from gymnasium_env.envs.f1_env import RewardFunctionPositionChange

from racesim.config import *

# %%
class F1EnvEvalCallback(EvalCallback):
    def __init__(
        self,
        eval_env: Union[gym.Env, VecEnv],
        callback_on_new_best: Optional[BaseCallback] = None,
        callback_after_eval: Optional[BaseCallback] = None,
        n_eval_episodes: int = 5,
        eval_freq: int = 10000,
        log_path: Optional[str] = None,
        best_model_save_path: Optional[str] = None,
        deterministic: bool = True,
        render: bool = False,
        verbose: int = 1,
        warn: bool = True,
        seed_eval_env: int = 0,
        reward_function: RewardFunction = None,
        grid_config: GridConfig = None
    ):
        super().__init__(eval_env,callback_on_new_best,callback_after_eval,n_eval_episodes,eval_freq,
                         log_path,best_model_save_path,deterministic,render,verbose,warn)
        self.seed_eval_env = seed_eval_env
        self.reward_function = reward_function
        self.grid_config = grid_config

    def _on_step(self) -> bool:
        continue_training = super()._on_step()
        if self.eval_freq > 0 and self.n_calls % self.eval_freq == 0:
            self.set_env_for_next_eval()
        return continue_training
        

    def set_env_for_next_eval(self) -> None:
        self.eval_env = gym.make("F1Env/Basic-v0", seed=self.seed_eval_env,
                                 reward_function=self.reward_function, grid_config=self.grid_config)

# %%
seed = 0
n_seeds = 3
seed_eval = 50
reward_function = RewardFunctionPositionChange()
grid_config = GridConfigSortedById()

# %%
for i in range(n_seeds):
    print("-----------------\n\n" + " RUN " + str(i) + "\n\n--------------------------")
    env = gym.make("F1Env/Basic-v0", seed=i, reward_function=reward_function, grid_config=grid_config)
    env_to_eval = gym.make("F1Env/Basic-v0", seed=seed_eval, reward_function=reward_function, grid_config=grid_config)

    eval_callback = F1EnvEvalCallback(eval_env=env_to_eval, best_model_save_path="./logs_" + str(i) + "/",
                             log_path="./logs_" + str(i) + "/", n_eval_episodes=20, eval_freq=25000,
                             deterministic=True, render=False, seed_eval_env=seed_eval,
                                      reward_function=reward_function, grid_config=grid_config)

    model_reward_position_change = DQN("MlpPolicy", env, gamma=1, buffer_size=100000, learning_starts=5000,
                                            train_freq=(16,"step"), exploration_initial_eps=0.25, exploration_fraction=0.2,
                                            exploration_final_eps=0.020, learning_rate=0.00005,
                                            batch_size=256,
                                            verbose=0, tensorboard_log="./dqn_r1/", seed=i)
    model_reward_position_change.learn(total_timesteps=1e6, callback=eval_callback)
    model_reward_position_change.save(path="./model_reward_position_change_"+str(i))
# Out:
# -----------------
#
#  RUN 0
#
# --------------------------
# /home/usuario/miniconda3/envs/rfl/lib/python3.11/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Eval num_timesteps=25000, episode_reward=-1.00 +/- 0.00
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=50000, episode_reward=-0.80 +/- 0.40
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=75000, episode_reward=-1.00 +/- 0.00
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=100000, episode_reward=-1.00 +/- 0.00
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=125000, episode_reward=-0.95 +/- 0.22
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=150000, episode_reward=-0.90 +/- 0.30
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=175000, episode_reward=-0.65 +/- 0.48
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=200000, episode_reward=-0.85 +/- 0.36
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=225000, episode_reward=-0.85 +/- 0.36
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=250000, episode_reward=-0.30 +/- 0.46
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=275000, episode_reward=-0.30 +/- 0.56
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=300000, episode_reward=0.65 +/- 2.03
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=325000, episode_reward=1.55 +/- 3.14
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=350000, episode_reward=0.85 +/- 1.59
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=375000, episode_reward=2.35 +/- 3.57
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=400000, episode_reward=1.65 +/- 3.88
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=425000, episode_reward=2.75 +/- 4.04
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=450000, episode_reward=-0.40 +/- 0.58
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=475000, episode_reward=0.45 +/- 2.36
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=500000, episode_reward=0.75 +/- 1.81
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=525000, episode_reward=1.75 +/- 3.88
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=550000, episode_reward=2.05 +/- 3.07
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=575000, episode_reward=2.75 +/- 2.70
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=600000, episode_reward=2.00 +/- 2.98
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=625000, episode_reward=2.35 +/- 5.51
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=650000, episode_reward=0.70 +/- 2.30
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=675000, episode_reward=2.10 +/- 3.95
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=700000, episode_reward=3.35 +/- 4.42
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=725000, episode_reward=4.15 +/- 6.53
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=750000, episode_reward=4.60 +/- 6.51
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=775000, episode_reward=4.45 +/- 5.84
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=800000, episode_reward=6.35 +/- 6.85
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=825000, episode_reward=6.70 +/- 5.09
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=850000, episode_reward=7.10 +/- 6.56
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=875000, episode_reward=4.65 +/- 5.76
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=900000, episode_reward=6.15 +/- 7.38
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=925000, episode_reward=5.70 +/- 4.35
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=950000, episode_reward=4.85 +/- 6.57
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=975000, episode_reward=4.70 +/- 5.03
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=1000000, episode_reward=5.80 +/- 5.63
# Episode length: 77.00 +/- 0.00
# -----------------
#
#  RUN 1
#
# --------------------------
# Eval num_timesteps=25000, episode_reward=-1.00 +/- 0.00
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=50000, episode_reward=-0.95 +/- 0.22
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=75000, episode_reward=-1.00 +/- 0.00
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=100000, episode_reward=-1.00 +/- 0.00
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=125000, episode_reward=-1.00 +/- 0.00
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=150000, episode_reward=-0.85 +/- 0.36
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=175000, episode_reward=-0.75 +/- 0.43
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=200000, episode_reward=-0.65 +/- 0.48
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=225000, episode_reward=-0.60 +/- 0.49
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=250000, episode_reward=-0.20 +/- 0.40
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=275000, episode_reward=0.45 +/- 2.04
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=300000, episode_reward=1.85 +/- 4.08
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=325000, episode_reward=0.80 +/- 2.69
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=350000, episode_reward=0.65 +/- 1.46
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=375000, episode_reward=0.10 +/- 0.62
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=400000, episode_reward=0.10 +/- 2.57
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=425000, episode_reward=0.25 +/- 6.28
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=450000, episode_reward=1.25 +/- 3.30
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=475000, episode_reward=1.00 +/- 2.45
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=500000, episode_reward=1.30 +/- 2.97
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=525000, episode_reward=1.40 +/- 2.99
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=550000, episode_reward=0.25 +/- 1.22
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=575000, episode_reward=3.20 +/- 5.25
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=600000, episode_reward=1.05 +/- 3.20
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=625000, episode_reward=2.35 +/- 4.10
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=650000, episode_reward=0.95 +/- 3.80
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=675000, episode_reward=2.95 +/- 3.88
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=700000, episode_reward=4.75 +/- 5.09
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=725000, episode_reward=2.95 +/- 4.34
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=750000, episode_reward=5.05 +/- 3.97
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=775000, episode_reward=5.90 +/- 5.52
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=800000, episode_reward=6.20 +/- 5.32
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=825000, episode_reward=5.30 +/- 4.86
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=850000, episode_reward=5.60 +/- 4.85
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=875000, episode_reward=5.55 +/- 3.94
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=900000, episode_reward=9.45 +/- 5.45
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=925000, episode_reward=7.90 +/- 6.00
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=950000, episode_reward=8.15 +/- 6.26
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=975000, episode_reward=8.90 +/- 5.77
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=1000000, episode_reward=7.50 +/- 5.25
# Episode length: 77.00 +/- 0.00
# -----------------
#
#  RUN 2
#
# --------------------------
# Eval num_timesteps=25000, episode_reward=-1.00 +/- 0.00
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=50000, episode_reward=-0.70 +/- 0.46
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=75000, episode_reward=-0.95 +/- 0.22
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=100000, episode_reward=-0.95 +/- 0.22
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=125000, episode_reward=-0.95 +/- 0.22
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=150000, episode_reward=-0.95 +/- 0.22
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=175000, episode_reward=-0.95 +/- 0.22
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=200000, episode_reward=-0.70 +/- 0.46
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=225000, episode_reward=-0.45 +/- 0.50
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=250000, episode_reward=-0.25 +/- 0.43
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=275000, episode_reward=2.75 +/- 5.15
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=300000, episode_reward=0.75 +/- 2.02
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=325000, episode_reward=1.75 +/- 2.68
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=350000, episode_reward=1.40 +/- 2.20
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=375000, episode_reward=2.75 +/- 3.75
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=400000, episode_reward=2.00 +/- 3.52
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=425000, episode_reward=2.25 +/- 4.15
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=450000, episode_reward=2.00 +/- 4.55
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=475000, episode_reward=2.00 +/- 3.38
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=500000, episode_reward=1.95 +/- 3.06
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=525000, episode_reward=2.30 +/- 3.23
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=550000, episode_reward=2.45 +/- 3.40
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=575000, episode_reward=3.80 +/- 5.09
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=600000, episode_reward=1.10 +/- 3.25
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=625000, episode_reward=5.20 +/- 5.58
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=650000, episode_reward=3.85 +/- 5.34
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=675000, episode_reward=2.50 +/- 3.73
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=700000, episode_reward=6.80 +/- 4.88
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=725000, episode_reward=5.85 +/- 4.65
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=750000, episode_reward=8.75 +/- 4.58
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=775000, episode_reward=8.50 +/- 5.62
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=800000, episode_reward=8.20 +/- 3.94
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=825000, episode_reward=8.45 +/- 5.64
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=850000, episode_reward=7.00 +/- 4.48
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=875000, episode_reward=9.80 +/- 5.12
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=900000, episode_reward=6.40 +/- 5.99
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=925000, episode_reward=7.90 +/- 5.37
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=950000, episode_reward=8.15 +/- 4.27
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=975000, episode_reward=8.60 +/- 5.35
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=1000000, episode_reward=7.15 +/- 4.91
# Episode length: 77.00 +/- 0.00

# %%
# import numpy as np
# from tqdm import tqdm
# import torch
# from stable_baselines3.common.utils import obs_as_tensor
# env_to_test = gym.make("F1Env/Basic-v0")

# %%
# agent = model_reward_position_change
# stops = 0

# for episode in tqdm(range(1)):
#     t = 0
#     total_rw = 0
#     obs, info = env_to_test.reset()
#     print(env_to_test.our_driver.tyre.__dict__)
#     # print(obs)
#     # print("------")
#     print("START POSITION: ", env_to_test.our_driver.position)
#     done = False

#     # play one episode
#     while not done:
#         # display(env_to_test.race_simulation.to_df())
#         action, _ = agent.predict(obs, deterministic=True)
#         with torch.no_grad():
#             observation = obs.reshape((-1,) + agent.observation_space.shape)
#             observation = obs_as_tensor(observation, 'cpu')
#             q_values = agent.q_net(observation)
#             # print(q_values)
#         if action != 0:
#             stops+=1
#             print(action, " - laps to go: ", env_to_test.our_driver.laps_to_go, " - position: ", env_to_test.our_driver.position)
#             print(q_values)
#         next_obs, reward, terminated, truncated, info = env_to_test.step(action)
#         # print('REWARDA: ', reward)

#         total_rw += reward

#         done = terminated or truncated
#         obs = next_obs
#         # print(obs)
#         # print("------")
#         t+=1

#     # print("Reward: " , total_rw)
# # display(env_to_test.race_simulation.to_df())
# print("Reward: " , total_rw, " - ", "Stops: ", stops)
# env_to_test.race_simulation.driver_being_controlled.position

# %%
# env_to_test.race_simulation.to_df()
