# %%
from sb3_contrib import QRDQN
from stable_baselines3.dqn import MlpPolicy
from typing import TYPE_CHECKING, Any, Callable, Dict, List, Optional, Union
from stable_baselines3.common.callbacks import EvalCallback, BaseCallback
from stable_baselines3.common.vec_env import DummyVecEnv, VecEnv, sync_envs_normalization
from stable_baselines3.common.monitor import Monitor
import gymnasium as gym

# %%
from gymnasium_env.envs.f1_env import RewardFunction
from gymnasium_env.envs.f1_env import RewardFunctionPerPositionAtFinalLap

from racesim.config import GridConfigMixed
from racesim.config import GridConfig

# %%
class F1EnvEvalCallback(EvalCallback):
    def __init__(
        self,
        eval_env: Union[gym.Env, VecEnv],
        callback_on_new_best: Optional[BaseCallback] = None,
        callback_after_eval: Optional[BaseCallback] = None,
        n_eval_episodes: int = 5,
        eval_freq: int = 10000,
        log_path: Optional[str] = None,
        best_model_save_path: Optional[str] = None,
        deterministic: bool = True,
        render: bool = False,
        verbose: int = 1,
        warn: bool = True,
        seed_eval_env: int = 0,
        reward_function: RewardFunction = None,
        grid_config: GridConfig = None
    ):
        super().__init__(eval_env,callback_on_new_best,callback_after_eval,n_eval_episodes,eval_freq,
                         log_path,best_model_save_path,deterministic,render,verbose,warn)
        self.seed_eval_env = seed_eval_env
        self.reward_function = reward_function
        self.grid_config = grid_config

    def _on_step(self) -> bool:
        continue_training = super()._on_step()
        if self.eval_freq > 0 and self.n_calls % self.eval_freq == 0:
            self.set_env_for_next_eval()
        return continue_training
        

    def set_env_for_next_eval(self) -> None:
        self.eval_env = gym.make("F1Env/Basic-v0", seed=self.seed_eval_env,
                                 reward_function=self.reward_function, grid_config=self.grid_config)

# %%
seed = 0
n_seeds = 1
seed_eval = 50
reward_function = RewardFunctionPerPositionAtFinalLap()

grid_config = GridConfigMixed()
policy_kwargs = dict(n_quantiles=21)

# %%
for i in range(n_seeds):
    print("-----------------\n\n" + " RUN " + str(i) + "\n\n--------------------------")
    env = gym.make("F1Env/Basic-v0", seed=i, reward_function=reward_function, grid_config=grid_config)
    env_to_eval = gym.make("F1Env/Basic-v0", seed=seed_eval, reward_function=reward_function, grid_config=grid_config)

    eval_callback = F1EnvEvalCallback(eval_env=env_to_eval, best_model_save_path="./logs_" + str(i) + "/",
                             log_path="./logs_" + str(i) + "/", n_eval_episodes=20, eval_freq=25000,
                             deterministic=True, render=False, seed_eval_env=seed_eval,
                                      reward_function=reward_function, grid_config=grid_config)

    model_reward_position_change = QRDQN("MlpPolicy", env, gamma=1, buffer_size=100000, learning_starts=5000,
                                            train_freq=(16,"step"), exploration_initial_eps=0.25, exploration_fraction=0.2,
                                            exploration_final_eps=0.020, learning_rate=0.00005,
                                            batch_size=256, policy_kwargs=policy_kwargs,
                                            verbose=0, tensorboard_log="./qr-dqn_r3/", seed=i)
    model_reward_position_change.learn(total_timesteps=2e6, callback=eval_callback)
    model_reward_position_change.save(path="./model_reward_position_change_"+str(i))
# Out:
# -----------------
#
#  RUN 0
#
# --------------------------
# /home/usuario/miniconda3/envs/rfl/lib/python3.11/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Eval num_timesteps=25000, episode_reward=-1.00 +/- 0.00
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=50000, episode_reward=-0.75 +/- 0.43
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=75000, episode_reward=-0.05 +/- 0.22
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=100000, episode_reward=-0.25 +/- 0.43
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=125000, episode_reward=-0.33 +/- 0.50
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=150000, episode_reward=-0.29 +/- 1.06
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=175000, episode_reward=-0.34 +/- 1.55
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=200000, episode_reward=0.46 +/- 2.14
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=225000, episode_reward=1.75 +/- 2.31
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=250000, episode_reward=2.34 +/- 1.66
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=275000, episode_reward=0.59 +/- 0.83
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=300000, episode_reward=0.68 +/- 2.12
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=325000, episode_reward=0.85 +/- 1.74
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=350000, episode_reward=2.50 +/- 2.66
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=375000, episode_reward=1.85 +/- 2.02
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=400000, episode_reward=1.02 +/- 2.53
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=425000, episode_reward=0.47 +/- 2.16
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=450000, episode_reward=2.09 +/- 1.84
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=475000, episode_reward=0.97 +/- 1.09
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=500000, episode_reward=1.90 +/- 2.21
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=525000, episode_reward=0.60 +/- 2.02
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=550000, episode_reward=2.27 +/- 3.12
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=575000, episode_reward=1.59 +/- 3.68
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=600000, episode_reward=3.08 +/- 5.02
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=625000, episode_reward=1.07 +/- 2.68
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=650000, episode_reward=1.90 +/- 3.64
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=675000, episode_reward=0.66 +/- 2.00
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=700000, episode_reward=1.16 +/- 3.49
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=725000, episode_reward=1.89 +/- 3.86
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=750000, episode_reward=1.40 +/- 3.57
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=775000, episode_reward=1.74 +/- 3.93
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=800000, episode_reward=4.41 +/- 5.58
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=825000, episode_reward=1.34 +/- 3.12
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=850000, episode_reward=2.39 +/- 3.69
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=875000, episode_reward=1.79 +/- 3.01
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=900000, episode_reward=2.11 +/- 3.25
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=925000, episode_reward=1.60 +/- 1.95
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=950000, episode_reward=1.55 +/- 2.04
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=975000, episode_reward=1.05 +/- 1.52
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=1000000, episode_reward=2.58 +/- 2.00
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=1025000, episode_reward=1.66 +/- 1.85
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=1050000, episode_reward=1.61 +/- 2.21
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=1075000, episode_reward=1.14 +/- 2.06
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=1100000, episode_reward=1.99 +/- 3.12
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=1125000, episode_reward=2.59 +/- 3.05
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=1150000, episode_reward=2.62 +/- 3.39
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=1175000, episode_reward=1.98 +/- 4.06
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=1200000, episode_reward=4.38 +/- 5.05
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=1225000, episode_reward=5.53 +/- 5.08
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=1250000, episode_reward=3.99 +/- 4.08
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=1275000, episode_reward=3.05 +/- 2.58
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=1300000, episode_reward=4.39 +/- 4.54
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=1325000, episode_reward=5.85 +/- 4.48
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=1350000, episode_reward=4.46 +/- 4.25
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=1375000, episode_reward=3.59 +/- 3.70
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=1400000, episode_reward=6.09 +/- 4.02
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=1425000, episode_reward=4.72 +/- 4.71
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=1450000, episode_reward=5.81 +/- 4.34
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=1475000, episode_reward=5.08 +/- 3.34
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=1500000, episode_reward=5.53 +/- 4.46
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=1525000, episode_reward=6.90 +/- 4.08
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=1550000, episode_reward=4.96 +/- 3.99
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=1575000, episode_reward=6.84 +/- 4.51
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=1600000, episode_reward=6.54 +/- 4.74
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=1625000, episode_reward=6.84 +/- 4.35
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=1650000, episode_reward=6.83 +/- 3.48
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=1675000, episode_reward=5.92 +/- 3.51
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=1700000, episode_reward=6.56 +/- 3.54
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=1725000, episode_reward=5.90 +/- 4.02
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=1750000, episode_reward=4.83 +/- 4.45
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=1775000, episode_reward=6.65 +/- 3.81
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=1800000, episode_reward=6.69 +/- 3.70
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=1825000, episode_reward=6.80 +/- 3.85
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=1850000, episode_reward=5.97 +/- 4.14
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=1875000, episode_reward=6.94 +/- 5.23
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=1900000, episode_reward=5.70 +/- 4.26
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=1925000, episode_reward=6.59 +/- 4.15
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=1950000, episode_reward=6.67 +/- 4.67
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=1975000, episode_reward=8.45 +/- 4.31
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=2000000, episode_reward=7.31 +/- 4.80
# Episode length: 77.00 +/- 0.00

# %%
# import numpy as np
# from tqdm import tqdm
# import torch
# from stable_baselines3.common.utils import obs_as_tensor
# env_to_test = gym.make("F1Env/Basic-v0")

# %%
# agent = model_reward_position_change
# stops = 0

# for episode in tqdm(range(1)):
#     t = 0
#     total_rw = 0
#     obs, info = env_to_test.reset()
#     print(env_to_test.our_driver.tyre.__dict__)
#     # print(obs)
#     # print("------")
#     print("START POSITION: ", env_to_test.our_driver.position)
#     done = False

#     # play one episode
#     while not done:
#         # display(env_to_test.race_simulation.to_df())
#         action, _ = agent.predict(obs, deterministic=True)
#         with torch.no_grad():
#             observation = obs.reshape((-1,) + agent.observation_space.shape)
#             observation = obs_as_tensor(observation, 'cpu')
#             q_values = agent.q_net(observation)
#             # print(q_values)
#         if action != 0:
#             stops+=1
#             print(action, " - laps to go: ", env_to_test.our_driver.laps_to_go, " - position: ", env_to_test.our_driver.position)
#             print(q_values)
#         next_obs, reward, terminated, truncated, info = env_to_test.step(action)
#         # print('REWARDA: ', reward)

#         total_rw += reward

#         done = terminated or truncated
#         obs = next_obs
#         # print(obs)
#         # print("------")
#         t+=1

#     # print("Reward: " , total_rw)
# # display(env_to_test.race_simulation.to_df())
# print("Reward: " , total_rw, " - ", "Stops: ", stops)
# env_to_test.race_simulation.driver_being_controlled.position

# %%
# env_to_test.race_simulation.to_df()
