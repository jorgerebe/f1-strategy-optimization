# %%
from sb3_contrib import QRDQN
from stable_baselines3.dqn import MlpPolicy
from typing import TYPE_CHECKING, Any, Callable, Dict, List, Optional, Union
from stable_baselines3.common.callbacks import EvalCallback, BaseCallback
from stable_baselines3.common.vec_env import DummyVecEnv, VecEnv, sync_envs_normalization
from stable_baselines3.common.monitor import Monitor
import gymnasium as gym

# %%
from gymnasium_env.envs.f1_env import RewardFunction
from gymnasium_env.envs.f1_env import RewardFunctionPerPositionAtFinalLap

from racesim.config import GridConfigMixed
from racesim.config import GridConfig

# %%
class F1EnvEvalCallback(EvalCallback):
    def __init__(
        self,
        eval_env: Union[gym.Env, VecEnv],
        callback_on_new_best: Optional[BaseCallback] = None,
        callback_after_eval: Optional[BaseCallback] = None,
        n_eval_episodes: int = 5,
        eval_freq: int = 10000,
        log_path: Optional[str] = None,
        best_model_save_path: Optional[str] = None,
        deterministic: bool = True,
        render: bool = False,
        verbose: int = 1,
        warn: bool = True,
        seed_eval_env: int = 0,
        reward_function: RewardFunction = None,
        grid_config: GridConfig = None
    ):
        super().__init__(eval_env,callback_on_new_best,callback_after_eval,n_eval_episodes,eval_freq,
                         log_path,best_model_save_path,deterministic,render,verbose,warn)
        self.seed_eval_env = seed_eval_env
        self.reward_function = reward_function
        self.grid_config = grid_config

    def _on_step(self) -> bool:
        continue_training = super()._on_step()
        if self.eval_freq > 0 and self.n_calls % self.eval_freq == 0:
            self.set_env_for_next_eval()
        return continue_training
        

    def set_env_for_next_eval(self) -> None:
        self.eval_env = gym.make("F1Env/Basic-v0", seed=self.seed_eval_env,
                                 reward_function=self.reward_function, grid_config=self.grid_config)

# %%
seed = 0
n_seeds = 3
seed_eval = 50
reward_function = RewardFunctionPerPositionAtFinalLap()

grid_config = GridConfigMixed()
policy_kwargs = dict(n_quantiles=21)

# %%
for i in range(n_seeds):
    print("-----------------\n\n" + " RUN " + str(i) + "\n\n--------------------------")
    env = gym.make("F1Env/Basic-v0", seed=i, reward_function=reward_function, grid_config=grid_config)
    env_to_eval = gym.make("F1Env/Basic-v0", seed=seed_eval, reward_function=reward_function, grid_config=grid_config)

    eval_callback = F1EnvEvalCallback(eval_env=env_to_eval, best_model_save_path="./logs_" + str(i) + "/",
                             log_path="./logs_" + str(i) + "/", n_eval_episodes=20, eval_freq=25000,
                             deterministic=True, render=False, seed_eval_env=seed_eval,
                                      reward_function=reward_function, grid_config=grid_config)

    model_reward_position_change = QRDQN("MlpPolicy", env, gamma=1, buffer_size=100000, learning_starts=5000,
                                            train_freq=(16,"step"), exploration_initial_eps=0.25, exploration_fraction=0.2,
                                            exploration_final_eps=0.020, learning_rate=0.00005,
                                            batch_size=256, policy_kwargs=policy_kwargs,
                                            verbose=0, tensorboard_log="./qr-dqn_r3/", seed=i)
    model_reward_position_change.learn(total_timesteps=1e6, callback=eval_callback)
    model_reward_position_change.save(path="./model_reward_position_change_"+str(i))
# Out:
# -----------------
#
#  RUN 0
#
# --------------------------
# /home/usuario/miniconda3/envs/rfl/lib/python3.11/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Eval num_timesteps=25000, episode_reward=-1.00 +/- 0.00
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=50000, episode_reward=-0.50 +/- 0.50
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=75000, episode_reward=-0.15 +/- 0.36
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=100000, episode_reward=-0.35 +/- 0.48
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=125000, episode_reward=0.38 +/- 3.46
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=150000, episode_reward=2.52 +/- 5.30
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=175000, episode_reward=1.23 +/- 3.10
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=200000, episode_reward=3.46 +/- 3.94
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=225000, episode_reward=2.01 +/- 2.59
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=250000, episode_reward=2.42 +/- 2.50
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=275000, episode_reward=2.50 +/- 2.77
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=300000, episode_reward=1.26 +/- 1.48
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=325000, episode_reward=0.94 +/- 2.24
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=350000, episode_reward=1.09 +/- 1.83
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=375000, episode_reward=0.69 +/- 1.56
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=400000, episode_reward=3.04 +/- 3.94
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=425000, episode_reward=3.02 +/- 3.92
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=450000, episode_reward=2.02 +/- 2.00
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=475000, episode_reward=1.80 +/- 2.58
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=500000, episode_reward=3.88 +/- 3.52
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=525000, episode_reward=2.58 +/- 2.71
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=550000, episode_reward=2.39 +/- 2.63
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=575000, episode_reward=0.96 +/- 1.88
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=600000, episode_reward=0.88 +/- 2.32
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=625000, episode_reward=0.80 +/- 1.61
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=650000, episode_reward=0.78 +/- 1.77
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=675000, episode_reward=0.95 +/- 2.62
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=700000, episode_reward=0.28 +/- 0.51
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=725000, episode_reward=-0.17 +/- 0.52
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=750000, episode_reward=-0.03 +/- 0.62
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=775000, episode_reward=0.45 +/- 0.85
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=800000, episode_reward=0.62 +/- 0.95
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=825000, episode_reward=0.95 +/- 3.33
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=850000, episode_reward=2.26 +/- 2.84
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=875000, episode_reward=1.16 +/- 1.17
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=900000, episode_reward=1.99 +/- 3.28
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=925000, episode_reward=2.45 +/- 2.60
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=950000, episode_reward=1.00 +/- 1.40
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=975000, episode_reward=1.02 +/- 2.44
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=1000000, episode_reward=0.69 +/- 1.84
# Episode length: 77.00 +/- 0.00
# -----------------
#
#  RUN 1
#
# --------------------------
# Eval num_timesteps=25000, episode_reward=-1.00 +/- 0.00
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=50000, episode_reward=-0.35 +/- 0.48
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=75000, episode_reward=-0.35 +/- 0.48
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=100000, episode_reward=-0.25 +/- 0.63
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=125000, episode_reward=2.02 +/- 3.22
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=150000, episode_reward=0.09 +/- 0.99
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=175000, episode_reward=3.80 +/- 4.20
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=200000, episode_reward=1.41 +/- 2.25
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=225000, episode_reward=1.69 +/- 2.21
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=250000, episode_reward=1.77 +/- 2.89
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=275000, episode_reward=2.45 +/- 3.55
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=300000, episode_reward=1.80 +/- 2.55
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=325000, episode_reward=3.00 +/- 3.21
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=350000, episode_reward=2.24 +/- 3.13
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=375000, episode_reward=2.69 +/- 2.96
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=400000, episode_reward=1.00 +/- 2.09
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=425000, episode_reward=2.71 +/- 2.88
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=450000, episode_reward=4.47 +/- 5.55
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=475000, episode_reward=2.34 +/- 2.66
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=500000, episode_reward=1.68 +/- 1.92
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=525000, episode_reward=1.11 +/- 2.13
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=550000, episode_reward=1.64 +/- 3.38
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=575000, episode_reward=0.81 +/- 2.09
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=600000, episode_reward=-0.15 +/- 4.13
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=625000, episode_reward=2.52 +/- 5.11
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=650000, episode_reward=0.62 +/- 1.29
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=675000, episode_reward=1.12 +/- 2.89
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=700000, episode_reward=1.81 +/- 3.50
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=725000, episode_reward=0.70 +/- 3.54
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=750000, episode_reward=0.19 +/- 1.68
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=775000, episode_reward=1.94 +/- 2.48
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=800000, episode_reward=1.06 +/- 1.91
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=825000, episode_reward=0.66 +/- 1.83
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=850000, episode_reward=1.46 +/- 1.99
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=875000, episode_reward=0.95 +/- 2.27
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=900000, episode_reward=1.25 +/- 2.11
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=925000, episode_reward=4.01 +/- 5.05
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=950000, episode_reward=3.30 +/- 3.35
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=975000, episode_reward=0.99 +/- 2.90
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=1000000, episode_reward=1.77 +/- 3.79
# Episode length: 77.00 +/- 0.00
# -----------------
#
#  RUN 2
#
# --------------------------
# Eval num_timesteps=25000, episode_reward=-1.00 +/- 0.00
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=50000, episode_reward=-0.95 +/- 0.22
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=75000, episode_reward=-0.30 +/- 0.46
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=100000, episode_reward=-0.35 +/- 0.48
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=125000, episode_reward=-0.09 +/- 0.47
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=150000, episode_reward=-0.05 +/- 0.22
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=175000, episode_reward=0.55 +/- 1.72
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=200000, episode_reward=2.51 +/- 4.88
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=225000, episode_reward=1.75 +/- 2.31
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=250000, episode_reward=1.61 +/- 2.49
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=275000, episode_reward=1.50 +/- 2.30
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=300000, episode_reward=1.79 +/- 2.82
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=325000, episode_reward=0.72 +/- 1.45
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=350000, episode_reward=1.66 +/- 1.97
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=375000, episode_reward=1.26 +/- 2.39
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=400000, episode_reward=1.55 +/- 2.12
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=425000, episode_reward=3.10 +/- 3.29
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=450000, episode_reward=1.16 +/- 2.63
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=475000, episode_reward=2.02 +/- 2.37
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=500000, episode_reward=2.06 +/- 3.20
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=525000, episode_reward=3.16 +/- 3.79
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=550000, episode_reward=2.84 +/- 5.07
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=575000, episode_reward=1.93 +/- 2.47
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=600000, episode_reward=3.41 +/- 4.33
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=625000, episode_reward=0.41 +/- 0.59
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=650000, episode_reward=0.46 +/- 1.00
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=675000, episode_reward=0.07 +/- 0.65
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=700000, episode_reward=-0.23 +/- 1.58
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=725000, episode_reward=0.61 +/- 3.02
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=750000, episode_reward=1.18 +/- 3.67
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=775000, episode_reward=2.35 +/- 5.02
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=800000, episode_reward=0.04 +/- 2.16
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=825000, episode_reward=1.52 +/- 3.29
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=850000, episode_reward=1.29 +/- 2.09
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=875000, episode_reward=2.45 +/- 2.48
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=900000, episode_reward=0.88 +/- 2.99
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=925000, episode_reward=1.73 +/- 2.85
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=950000, episode_reward=2.52 +/- 3.02
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=975000, episode_reward=2.84 +/- 2.66
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=1000000, episode_reward=2.76 +/- 2.09
# Episode length: 77.00 +/- 0.00

# %%
# import numpy as np
# from tqdm import tqdm
# import torch
# from stable_baselines3.common.utils import obs_as_tensor
# env_to_test = gym.make("F1Env/Basic-v0")

# %%
# agent = model_reward_position_change
# stops = 0

# for episode in tqdm(range(1)):
#     t = 0
#     total_rw = 0
#     obs, info = env_to_test.reset()
#     print(env_to_test.our_driver.tyre.__dict__)
#     # print(obs)
#     # print("------")
#     print("START POSITION: ", env_to_test.our_driver.position)
#     done = False

#     # play one episode
#     while not done:
#         # display(env_to_test.race_simulation.to_df())
#         action, _ = agent.predict(obs, deterministic=True)
#         with torch.no_grad():
#             observation = obs.reshape((-1,) + agent.observation_space.shape)
#             observation = obs_as_tensor(observation, 'cpu')
#             q_values = agent.q_net(observation)
#             # print(q_values)
#         if action != 0:
#             stops+=1
#             print(action, " - laps to go: ", env_to_test.our_driver.laps_to_go, " - position: ", env_to_test.our_driver.position)
#             print(q_values)
#         next_obs, reward, terminated, truncated, info = env_to_test.step(action)
#         # print('REWARDA: ', reward)

#         total_rw += reward

#         done = terminated or truncated
#         obs = next_obs
#         # print(obs)
#         # print("------")
#         t+=1

#     # print("Reward: " , total_rw)
# # display(env_to_test.race_simulation.to_df())
# print("Reward: " , total_rw, " - ", "Stops: ", stops)
# env_to_test.race_simulation.driver_being_controlled.position

# %%
# env_to_test.race_simulation.to_df()
