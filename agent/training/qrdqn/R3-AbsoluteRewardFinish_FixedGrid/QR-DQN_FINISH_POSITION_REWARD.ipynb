# %%
from sb3_contrib import QRDQN
from stable_baselines3.dqn import MlpPolicy
from typing import TYPE_CHECKING, Any, Callable, Dict, List, Optional, Union
from stable_baselines3.common.callbacks import EvalCallback, BaseCallback
from stable_baselines3.common.vec_env import DummyVecEnv, VecEnv, sync_envs_normalization
from stable_baselines3.common.monitor import Monitor
import gymnasium as gym

# %%
from gymnasium_env.envs.f1_env import RewardFunction
from gymnasium_env.envs.f1_env import RewardFunctionPerPositionAtFinalLap

from racesim.config import GridConfigSortedById
from racesim.config import GridConfig

# %%
class F1EnvEvalCallback(EvalCallback):
    def __init__(
        self,
        eval_env: Union[gym.Env, VecEnv],
        callback_on_new_best: Optional[BaseCallback] = None,
        callback_after_eval: Optional[BaseCallback] = None,
        n_eval_episodes: int = 5,
        eval_freq: int = 10000,
        log_path: Optional[str] = None,
        best_model_save_path: Optional[str] = None,
        deterministic: bool = True,
        render: bool = False,
        verbose: int = 1,
        warn: bool = True,
        seed_eval_env: int = 0,
        reward_function: RewardFunction = None,
        grid_config: GridConfig = None
    ):
        super().__init__(eval_env,callback_on_new_best,callback_after_eval,n_eval_episodes,eval_freq,
                         log_path,best_model_save_path,deterministic,render,verbose,warn)
        self.seed_eval_env = seed_eval_env
        self.reward_function = reward_function
        self.grid_config = grid_config

    def _on_step(self) -> bool:
        continue_training = super()._on_step()
        if self.eval_freq > 0 and self.n_calls % self.eval_freq == 0:
            self.set_env_for_next_eval()
        return continue_training
        

    def set_env_for_next_eval(self) -> None:
        self.eval_env = gym.make("F1Env/Basic-v0", seed=self.seed_eval_env,
                                 reward_function=self.reward_function, grid_config=self.grid_config)

# %%
seed = 0
n_seeds = 3
seed_eval = 50
reward_function = RewardFunctionPerPositionAtFinalLap()

grid_config = GridConfigSortedById()
policy_kwargs = dict(n_quantiles=21)

# %%
for i in range(n_seeds):
    print("-----------------\n\n" + " RUN " + str(i) + "\n\n--------------------------")
    env = gym.make("F1Env/Basic-v0", seed=i, reward_function=reward_function, grid_config=grid_config)
    env_to_eval = gym.make("F1Env/Basic-v0", seed=seed_eval, reward_function=reward_function, grid_config=grid_config)

    eval_callback = F1EnvEvalCallback(eval_env=env_to_eval, best_model_save_path="./logs_" + str(i) + "/",
                             log_path="./logs_" + str(i) + "/", n_eval_episodes=20, eval_freq=25000,
                             deterministic=True, render=False, seed_eval_env=seed_eval,
                                      reward_function=reward_function, grid_config=grid_config)

    model_reward_position_change = QRDQN("MlpPolicy", env, gamma=1, buffer_size=100000, learning_starts=5000,
                                            train_freq=(16,"step"), exploration_initial_eps=0.25, exploration_fraction=0.2,
                                            exploration_final_eps=0.020, learning_rate=0.00005,
                                            batch_size=256, policy_kwargs=policy_kwargs,
                                            verbose=0, tensorboard_log="./qr-dqn_r3/", seed=i)
    model_reward_position_change.learn(total_timesteps=1e6, callback=eval_callback)
    model_reward_position_change.save(path="./model_reward_position_change_"+str(i))
# Out:
# -----------------
#
#  RUN 0
#
# --------------------------
# /home/usuario/miniconda3/envs/rfl/lib/python3.11/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Eval num_timesteps=25000, episode_reward=-1.00 +/- 0.00
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=50000, episode_reward=-0.90 +/- 0.30
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=75000, episode_reward=-0.65 +/- 0.48
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=100000, episode_reward=-0.30 +/- 0.46
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=125000, episode_reward=-0.04 +/- 0.50
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=150000, episode_reward=-0.16 +/- 0.72
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=175000, episode_reward=0.47 +/- 1.47
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=200000, episode_reward=2.58 +/- 3.28
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=225000, episode_reward=1.69 +/- 1.93
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=250000, episode_reward=0.34 +/- 1.14
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=275000, episode_reward=0.65 +/- 1.64
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=300000, episode_reward=0.24 +/- 0.95
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=325000, episode_reward=0.74 +/- 2.45
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=350000, episode_reward=1.01 +/- 1.68
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=375000, episode_reward=2.46 +/- 3.14
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=400000, episode_reward=0.90 +/- 2.39
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=425000, episode_reward=1.29 +/- 2.02
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=450000, episode_reward=-0.05 +/- 0.22
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=475000, episode_reward=1.01 +/- 1.93
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=500000, episode_reward=1.20 +/- 1.72
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=525000, episode_reward=0.49 +/- 1.12
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=550000, episode_reward=0.04 +/- 0.09
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=575000, episode_reward=-0.44 +/- 3.57
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=600000, episode_reward=0.19 +/- 4.53
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=625000, episode_reward=0.34 +/- 0.84
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=650000, episode_reward=1.16 +/- 1.94
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=675000, episode_reward=0.45 +/- 1.28
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=700000, episode_reward=-0.04 +/- 0.64
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=725000, episode_reward=1.14 +/- 2.03
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=750000, episode_reward=0.76 +/- 1.30
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=775000, episode_reward=0.64 +/- 0.94
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=800000, episode_reward=1.45 +/- 3.35
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=825000, episode_reward=0.86 +/- 1.09
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=850000, episode_reward=1.12 +/- 2.09
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=875000, episode_reward=2.00 +/- 2.25
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=900000, episode_reward=2.55 +/- 2.53
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=925000, episode_reward=2.21 +/- 2.71
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=950000, episode_reward=2.90 +/- 2.08
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=975000, episode_reward=1.60 +/- 5.94
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=1000000, episode_reward=2.79 +/- 4.10
# Episode length: 77.00 +/- 0.00
# -----------------
#
#  RUN 1
#
# --------------------------
# Eval num_timesteps=25000, episode_reward=-1.00 +/- 0.00
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=50000, episode_reward=-0.65 +/- 0.48
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=75000, episode_reward=0.00 +/- 0.00
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=100000, episode_reward=-0.35 +/- 0.48
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=125000, episode_reward=0.12 +/- 0.61
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=150000, episode_reward=0.60 +/- 1.49
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=175000, episode_reward=0.51 +/- 1.42
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=200000, episode_reward=0.79 +/- 1.39
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=225000, episode_reward=1.21 +/- 2.10
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=250000, episode_reward=0.72 +/- 2.08
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=275000, episode_reward=0.29 +/- 0.32
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=300000, episode_reward=0.85 +/- 1.83
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=325000, episode_reward=1.16 +/- 1.92
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=350000, episode_reward=1.51 +/- 1.89
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=375000, episode_reward=1.80 +/- 2.28
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=400000, episode_reward=1.50 +/- 2.33
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=425000, episode_reward=0.56 +/- 2.23
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=450000, episode_reward=1.93 +/- 2.55
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=475000, episode_reward=0.90 +/- 1.79
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=500000, episode_reward=0.89 +/- 2.06
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=525000, episode_reward=0.93 +/- 1.72
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=550000, episode_reward=0.62 +/- 0.84
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=575000, episode_reward=1.40 +/- 2.37
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=600000, episode_reward=0.71 +/- 2.07
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=625000, episode_reward=0.44 +/- 0.74
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=650000, episode_reward=0.88 +/- 1.30
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=675000, episode_reward=0.53 +/- 0.82
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=700000, episode_reward=0.45 +/- 1.08
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=725000, episode_reward=0.62 +/- 0.74
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=750000, episode_reward=0.86 +/- 1.19
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=775000, episode_reward=0.80 +/- 0.94
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=800000, episode_reward=0.86 +/- 1.19
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=825000, episode_reward=0.06 +/- 0.85
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=850000, episode_reward=0.93 +/- 2.00
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=875000, episode_reward=1.45 +/- 1.82
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=900000, episode_reward=1.44 +/- 1.71
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=925000, episode_reward=1.95 +/- 2.07
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=950000, episode_reward=1.06 +/- 1.19
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=975000, episode_reward=1.36 +/- 1.39
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=1000000, episode_reward=1.12 +/- 1.32
# Episode length: 77.00 +/- 0.00
# -----------------
#
#  RUN 2
#
# --------------------------
# Eval num_timesteps=25000, episode_reward=-1.00 +/- 0.00
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=50000, episode_reward=-0.75 +/- 0.43
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=75000, episode_reward=-0.10 +/- 0.30
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=100000, episode_reward=-0.40 +/- 0.49
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=125000, episode_reward=-0.03 +/- 0.25
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=150000, episode_reward=0.03 +/- 0.08
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=175000, episode_reward=1.02 +/- 1.48
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=200000, episode_reward=0.03 +/- 1.93
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=225000, episode_reward=1.61 +/- 2.00
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=250000, episode_reward=1.49 +/- 1.57
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=275000, episode_reward=2.16 +/- 1.92
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=300000, episode_reward=2.17 +/- 2.26
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=325000, episode_reward=2.76 +/- 2.18
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=350000, episode_reward=0.19 +/- 1.11
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=375000, episode_reward=0.99 +/- 1.48
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=400000, episode_reward=0.60 +/- 1.40
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=425000, episode_reward=1.45 +/- 2.33
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=450000, episode_reward=1.85 +/- 2.37
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=475000, episode_reward=0.76 +/- 1.87
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=500000, episode_reward=0.53 +/- 1.48
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=525000, episode_reward=1.84 +/- 2.74
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=550000, episode_reward=1.62 +/- 2.42
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=575000, episode_reward=1.20 +/- 2.25
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=600000, episode_reward=1.48 +/- 1.94
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=625000, episode_reward=1.10 +/- 1.46
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=650000, episode_reward=1.70 +/- 2.42
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=675000, episode_reward=0.94 +/- 2.09
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=700000, episode_reward=0.60 +/- 1.01
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=725000, episode_reward=0.23 +/- 0.27
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=750000, episode_reward=-0.03 +/- 0.79
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=775000, episode_reward=0.33 +/- 0.51
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=800000, episode_reward=0.82 +/- 1.30
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=825000, episode_reward=1.19 +/- 1.69
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=850000, episode_reward=1.79 +/- 1.87
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=875000, episode_reward=1.51 +/- 1.37
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=900000, episode_reward=1.66 +/- 1.78
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=925000, episode_reward=2.24 +/- 2.02
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=950000, episode_reward=2.14 +/- 1.99
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=975000, episode_reward=1.51 +/- 2.43
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=1000000, episode_reward=3.01 +/- 2.15
# Episode length: 77.00 +/- 0.00
# New best mean reward!

# %%
# import numpy as np
# from tqdm import tqdm
# import torch
# from stable_baselines3.common.utils import obs_as_tensor
# env_to_test = gym.make("F1Env/Basic-v0")

# %%
# agent = model_reward_position_change
# stops = 0

# for episode in tqdm(range(1)):
#     t = 0
#     total_rw = 0
#     obs, info = env_to_test.reset()
#     print(env_to_test.our_driver.tyre.__dict__)
#     # print(obs)
#     # print("------")
#     print("START POSITION: ", env_to_test.our_driver.position)
#     done = False

#     # play one episode
#     while not done:
#         # display(env_to_test.race_simulation.to_df())
#         action, _ = agent.predict(obs, deterministic=True)
#         with torch.no_grad():
#             observation = obs.reshape((-1,) + agent.observation_space.shape)
#             observation = obs_as_tensor(observation, 'cpu')
#             q_values = agent.q_net(observation)
#             # print(q_values)
#         if action != 0:
#             stops+=1
#             print(action, " - laps to go: ", env_to_test.our_driver.laps_to_go, " - position: ", env_to_test.our_driver.position)
#             print(q_values)
#         next_obs, reward, terminated, truncated, info = env_to_test.step(action)
#         # print('REWARDA: ', reward)

#         total_rw += reward

#         done = terminated or truncated
#         obs = next_obs
#         # print(obs)
#         # print("------")
#         t+=1

#     # print("Reward: " , total_rw)
# # display(env_to_test.race_simulation.to_df())
# print("Reward: " , total_rw, " - ", "Stops: ", stops)
# env_to_test.race_simulation.driver_being_controlled.position

# %%
# env_to_test.race_simulation.to_df()
