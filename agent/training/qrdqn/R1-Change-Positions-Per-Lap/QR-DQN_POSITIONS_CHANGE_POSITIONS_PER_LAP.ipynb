# %%
from sb3_contrib import QRDQN
from stable_baselines3.dqn import MlpPolicy
from typing import TYPE_CHECKING, Any, Callable, Dict, List, Optional, Union
from stable_baselines3.common.callbacks import EvalCallback, BaseCallback
from stable_baselines3.common.vec_env import DummyVecEnv, VecEnv, sync_envs_normalization
from stable_baselines3.common.monitor import Monitor
import gymnasium as gym

# %%
from gymnasium_env.envs.f1_env import RewardFunction
from gymnasium_env.envs.f1_env import RewardFunctionPositionChange

from racesim.config import *

# %%
class F1EnvEvalCallback(EvalCallback):
    def __init__(
        self,
        eval_env: Union[gym.Env, VecEnv],
        callback_on_new_best: Optional[BaseCallback] = None,
        callback_after_eval: Optional[BaseCallback] = None,
        n_eval_episodes: int = 5,
        eval_freq: int = 10000,
        log_path: Optional[str] = None,
        best_model_save_path: Optional[str] = None,
        deterministic: bool = True,
        render: bool = False,
        verbose: int = 1,
        warn: bool = True,
        seed_eval_env: int = 0,
        reward_function: RewardFunction = None,
        grid_config: GridConfig = None
    ):
        super().__init__(eval_env,callback_on_new_best,callback_after_eval,n_eval_episodes,eval_freq,
                         log_path,best_model_save_path,deterministic,render,verbose,warn)
        self.seed_eval_env = seed_eval_env
        self.reward_function = reward_function
        self.grid_config = grid_config

    def _on_step(self) -> bool:
        continue_training = super()._on_step()
        if self.eval_freq > 0 and self.n_calls % self.eval_freq == 0:
            self.set_env_for_next_eval()
        return continue_training
        

    def set_env_for_next_eval(self) -> None:
        self.eval_env = gym.make("F1Env/Basic-v0", seed=self.seed_eval_env,
                                 reward_function=self.reward_function, grid_config=self.grid_config)

# %%
seed = 0
n_seeds = 3
seed_eval = 50
reward_function = RewardFunctionPositionChange()
grid_config = GridConfigSortedById()
policy_kwargs = dict(n_quantiles=21)

# %%
for i in range(n_seeds):
    print("-----------------\n\n" + " RUN " + str(i) + "\n\n--------------------------")
    env = gym.make("F1Env/Basic-v0", seed=i, reward_function=reward_function, grid_config=grid_config)
    env_to_eval = gym.make("F1Env/Basic-v0", seed=seed_eval, reward_function=reward_function, grid_config=grid_config)

    eval_callback = F1EnvEvalCallback(eval_env=env_to_eval, best_model_save_path="./logs_" + str(i) + "/",
                             log_path="./logs_" + str(i) + "/", n_eval_episodes=20, eval_freq=25000,
                             deterministic=True, render=False, seed_eval_env=seed_eval,
                                      reward_function=reward_function, grid_config=grid_config)

    model_reward_position_change = QRDQN("MlpPolicy", env, gamma=1, buffer_size=100000, learning_starts=5000,
                                            train_freq=(16,"step"), exploration_initial_eps=0.25, exploration_fraction=0.2,
                                            exploration_final_eps=0.020, learning_rate=0.00005,
                                            batch_size=256, policy_kwargs=policy_kwargs,
                                            verbose=0, tensorboard_log="./qr-dqn_r1/", seed=i)
    model_reward_position_change.learn(total_timesteps=1e6, callback=eval_callback)
    model_reward_position_change.save(path="./model_reward_position_change_"+str(i))
# Out:
# -----------------
#
#  RUN 0
#
# --------------------------
# /home/usuario/miniconda3/envs/rfl/lib/python3.11/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Eval num_timesteps=25000, episode_reward=-1.00 +/- 0.00
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=50000, episode_reward=-1.00 +/- 0.00
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=75000, episode_reward=-1.00 +/- 0.00
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=100000, episode_reward=-1.00 +/- 0.00
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=125000, episode_reward=-1.00 +/- 0.00
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=150000, episode_reward=-1.00 +/- 0.00
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=175000, episode_reward=-1.00 +/- 0.00
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=200000, episode_reward=-0.85 +/- 0.36
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=225000, episode_reward=-0.90 +/- 0.30
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=250000, episode_reward=-0.90 +/- 0.30
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=275000, episode_reward=-0.65 +/- 0.48
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=300000, episode_reward=0.25 +/- 2.41
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=325000, episode_reward=2.25 +/- 4.13
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=350000, episode_reward=-0.75 +/- 1.18
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=375000, episode_reward=0.35 +/- 2.41
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=400000, episode_reward=0.25 +/- 1.73
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=425000, episode_reward=0.30 +/- 2.30
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=450000, episode_reward=-0.30 +/- 0.95
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=475000, episode_reward=1.95 +/- 3.04
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=500000, episode_reward=0.65 +/- 2.37
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=525000, episode_reward=2.95 +/- 5.65
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=550000, episode_reward=3.00 +/- 4.97
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=575000, episode_reward=2.25 +/- 2.75
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=600000, episode_reward=2.95 +/- 3.31
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=625000, episode_reward=1.90 +/- 3.60
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=650000, episode_reward=2.25 +/- 3.77
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=675000, episode_reward=4.30 +/- 4.47
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=700000, episode_reward=4.90 +/- 3.88
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=725000, episode_reward=2.35 +/- 4.23
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=750000, episode_reward=6.40 +/- 5.94
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=775000, episode_reward=3.45 +/- 5.00
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=800000, episode_reward=2.80 +/- 3.19
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=825000, episode_reward=4.15 +/- 4.95
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=850000, episode_reward=3.15 +/- 4.09
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=875000, episode_reward=2.75 +/- 4.22
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=900000, episode_reward=3.30 +/- 4.72
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=925000, episode_reward=4.60 +/- 4.63
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=950000, episode_reward=2.00 +/- 3.16
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=975000, episode_reward=3.45 +/- 4.13
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=1000000, episode_reward=3.75 +/- 4.21
# Episode length: 77.00 +/- 0.00
# -----------------
#
#  RUN 1
#
# --------------------------
# Eval num_timesteps=25000, episode_reward=-1.00 +/- 0.00
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=50000, episode_reward=-1.00 +/- 0.00
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=75000, episode_reward=-1.00 +/- 0.00
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=100000, episode_reward=-1.00 +/- 0.00
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=125000, episode_reward=-1.00 +/- 0.00
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=150000, episode_reward=-1.00 +/- 0.00
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=175000, episode_reward=-1.00 +/- 0.00
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=200000, episode_reward=-1.00 +/- 0.00
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=225000, episode_reward=-0.85 +/- 0.36
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=250000, episode_reward=-1.35 +/- 2.01
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=275000, episode_reward=-1.15 +/- 1.39
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=300000, episode_reward=-0.40 +/- 0.49
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=325000, episode_reward=0.80 +/- 3.04
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=350000, episode_reward=-0.65 +/- 2.03
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=375000, episode_reward=0.85 +/- 2.87
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=400000, episode_reward=-0.70 +/- 1.05
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=425000, episode_reward=0.40 +/- 2.92
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=450000, episode_reward=-0.95 +/- 0.22
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=475000, episode_reward=3.15 +/- 4.43
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=500000, episode_reward=2.50 +/- 4.31
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=525000, episode_reward=0.75 +/- 2.70
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=550000, episode_reward=2.65 +/- 4.40
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=575000, episode_reward=4.80 +/- 5.22
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=600000, episode_reward=2.35 +/- 4.43
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=625000, episode_reward=3.35 +/- 4.43
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=650000, episode_reward=2.95 +/- 4.89
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=675000, episode_reward=2.35 +/- 4.13
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=700000, episode_reward=7.00 +/- 4.60
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=725000, episode_reward=4.95 +/- 4.21
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=750000, episode_reward=5.20 +/- 4.76
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=775000, episode_reward=7.50 +/- 4.66
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=800000, episode_reward=4.30 +/- 3.95
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=825000, episode_reward=5.80 +/- 3.57
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=850000, episode_reward=5.30 +/- 3.63
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=875000, episode_reward=5.10 +/- 4.11
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=900000, episode_reward=8.00 +/- 3.55
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=925000, episode_reward=3.25 +/- 4.01
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=950000, episode_reward=6.65 +/- 3.81
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=975000, episode_reward=4.45 +/- 3.83
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=1000000, episode_reward=4.60 +/- 3.25
# Episode length: 77.00 +/- 0.00
# -----------------
#
#  RUN 2
#
# --------------------------
# Eval num_timesteps=25000, episode_reward=-1.00 +/- 0.00
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=50000, episode_reward=-1.00 +/- 0.00
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=75000, episode_reward=-1.00 +/- 0.00
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=100000, episode_reward=-1.00 +/- 0.00
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=125000, episode_reward=-1.00 +/- 0.00
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=150000, episode_reward=-1.00 +/- 0.00
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=175000, episode_reward=-1.00 +/- 0.00
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=200000, episode_reward=-0.85 +/- 0.36
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=225000, episode_reward=-0.85 +/- 0.36
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=250000, episode_reward=-3.30 +/- 4.01
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=275000, episode_reward=-0.85 +/- 0.36
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=300000, episode_reward=-0.85 +/- 0.36
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=325000, episode_reward=-0.25 +/- 1.22
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=350000, episode_reward=-0.05 +/- 2.22
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=375000, episode_reward=0.60 +/- 2.63
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=400000, episode_reward=-0.75 +/- 0.43
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=425000, episode_reward=0.00 +/- 2.07
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=450000, episode_reward=-0.55 +/- 0.92
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=475000, episode_reward=0.35 +/- 2.35
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=500000, episode_reward=1.15 +/- 3.45
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=525000, episode_reward=1.95 +/- 3.97
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=550000, episode_reward=3.55 +/- 4.03
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=575000, episode_reward=2.15 +/- 3.90
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=600000, episode_reward=1.90 +/- 2.64
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=625000, episode_reward=2.95 +/- 3.34
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=650000, episode_reward=0.15 +/- 2.10
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=675000, episode_reward=5.15 +/- 4.49
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=700000, episode_reward=1.90 +/- 4.39
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=725000, episode_reward=0.70 +/- 2.70
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=750000, episode_reward=5.50 +/- 4.70
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=775000, episode_reward=8.20 +/- 5.38
# Episode length: 77.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=800000, episode_reward=3.85 +/- 5.58
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=825000, episode_reward=6.15 +/- 3.20
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=850000, episode_reward=2.80 +/- 3.68
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=875000, episode_reward=7.25 +/- 3.53
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=900000, episode_reward=5.65 +/- 3.10
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=925000, episode_reward=5.95 +/- 4.59
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=950000, episode_reward=5.90 +/- 3.05
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=975000, episode_reward=4.90 +/- 4.31
# Episode length: 77.00 +/- 0.00
# Eval num_timesteps=1000000, episode_reward=5.15 +/- 3.24
# Episode length: 77.00 +/- 0.00
